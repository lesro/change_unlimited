# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
irs_ind_income = pd.read_csv('../data/irs_individual_data/17zpallagi.csv')
irs_np = pd.read_csv('../data/irs_np_data/all_us_np_data.csv')
cen_income = pd.read_csv('../data/dp02_income_data.csv')

#load this took a second or two, literally, heavy for jup

# %% [markdown]
# ## IRS DF Scrub

# %%
#step 1: clean up irs dataset for columns that I will want.
# keep_columns = ['STATE', 'zipcode', 'agi_stub', 'A00100', 'A02650', 'A00200',]
column_dict = {'STATE':'State', 'zipcode': 'Zipcode', 'N1':'Number of returns',  'N02650': 'Number of returns with total income', 'A02650':'Total income amount', 'N00200':'Number of returns with salaries and wages','A00200': 'Salaries and wages amount'}

# %%
columns = []
for k, v in column_dict.items():
    columns.append(k)

# %%
irs_wip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166537 entries, 0 to 166536
# Data columns (total 7 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   STATE    166537 non-null  object
#  1   zipcode  166537 non-null  int64
#  2   N1       166537 non-null  float64
#  3   N02650   166537 non-null  float64
#  4   A02650   166537 non-null  float64
#  5   N00200   166537 non-null  float64
#  6   A00200   166537 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.9+ MB

# %%
irs_wip_df = irs_ind_income[['STATE',
 'zipcode',
 'N1',
 'N02650',
 'A02650',
 'N00200',
 'A00200']]

removed_zip_0 = irs_wip_df[irs_wip_df['zipcode'] != 0]
removed_zip_99999 = removed_zip_0[removed_zip_0['zipcode'] != 99999]

#started with 166537, after removing zips with 0 and 99999, left with 
#165923

#these rows are for areas that have pop under 100 and/or

# %%
irs_wip_df = removed_zip_99999

# %%
# new_header = cen_income.iloc[0] #grab the first row for the header
# cen_income = cen_income[1:] #take the data less the header row
# cen_income.columns = new_header #set the header row as the df header

cen_income.drop([cen_income.columns[0], cen_income.columns[1]], axis=1).to_csv('../data/dp02_income_data_clean.csv')

# %%
irs_wip_df.describe()
# Out:
#              zipcode             N1         N02650        A02650  \
# count  165925.000000  165925.000000  165925.000000  1.659250e+05
# mean    48866.056423     886.651439     886.650655  6.638068e+04
# std     27020.284037    1558.670376    1558.669152  2.109717e+05
# min      1001.000000       0.000000       0.000000  0.000000e+00
# 25%     27208.000000      70.000000      70.000000  4.255000e+03
# 50%     48876.000000     240.000000     240.000000  1.585300e+04
# 75%     70537.000000    1000.000000    1000.000000  6.237200e+04
# max     99901.000000   35090.000000   35090.000000  1.318729e+07
#
#               N00200        A00200
# count  165925.000000  1.659250e+05
# mean      739.653699  4.436999e+04
# std      1295.252193  1.114398e+05
# min         0.000000  0.000000e+00
# 25%        50.000000  2.886000e+03
# 50%       200.000000  1.069400e+04
# 75%       830.000000  4.397200e+04
# max     27580.000000  4.958266e+06

# %%
#identify if zipcodes are unique, they are not, group by them
irs_wip_df[irs_wip_df['zipcode']==78758]
# Out:
#        STATE  zipcode      N1  N02650    A02650  N00200    A00200
# 146566    TX    78758  7740.0  7740.0  109129.0  6350.0   89283.0
# 146567    TX    78758  7110.0  7110.0  260260.0  6600.0  232803.0
# 146568    TX    78758  3490.0  3490.0  215384.0  3250.0  189458.0
# 146569    TX    78758  1900.0  1900.0  165237.0  1750.0  139565.0
# 146570    TX    78758  2040.0  2040.0  270955.0  1890.0  226094.0
# 146571    TX    78758   440.0   440.0  196098.0   400.0   98984.0

# %%
#grouped zipcodes within states
irs_wip_df_grouped_zip = irs_wip_df.groupby(['STATE','zipcode'], as_index=False).sum()
irs_wip_df_grouped_zip.head()
# Out:
#   STATE  zipcode       N1   N02650     A02650   N00200    A00200
# 0    AK    99501   7740.0   7740.0   581650.0   6510.0  365039.0
# 1    AK    99502  11690.0  11690.0   996844.0  10090.0  668117.0
# 2    AK    99503   7670.0   7670.0   444587.0   6540.0  310717.0
# 3    AK    99504  19120.0  19120.0  1120829.0  16470.0  838127.0
# 4    AK    99505   2290.0   2290.0    89034.0   2250.0   85570.0

# %%
#calcualte average individual income by zip code
irs_wip_df_grouped_zip['avg_income'] = irs_wip_df_grouped_zip['A02650']/irs_wip_df_grouped_zip['N1']
irs_wip_df_grouped_zip.head()
# Out:
#   STATE  zipcode       N1   N02650     A02650   N00200    A00200  avg_income
# 0    AK    99501   7740.0   7740.0   581650.0   6510.0  365039.0   75.148579
# 1    AK    99502  11690.0  11690.0   996844.0  10090.0  668117.0   85.273225
# 2    AK    99503   7670.0   7670.0   444587.0   6540.0  310717.0   57.964407
# 3    AK    99504  19120.0  19120.0  1120829.0  16470.0  838127.0   58.620764
# 4    AK    99505   2290.0   2290.0    89034.0   2250.0   85570.0   38.879476

# %%
irs_wip_df_grouped_state = irs_wip_df.groupby(['STATE'], as_index=False).sum()
irs_wip_df_grouped_state.drop('zipcode', axis=1)
irs_wip_df_grouped_state['avg_income'] = irs_wip_df_grouped_state['A02650']/irs_wip_df_grouped_state['N1']

# %%
irs_wip_df_grouped_state.head()
# Out:
#   STATE    zipcode          N1      N02650        A02650      N00200  \
# 0    AK   31685718    271430.0    271430.0  1.981859e+07    228620.0
# 1    AL  123817728   2004610.0   2004610.0  1.182767e+08   1680900.0
# 2    AR  211956168   1184370.0   1184370.0  7.319250e+07    996860.0
# 3    AZ  150362748   2826980.0   2826980.0  1.932967e+08   2307910.0
# 4    CA  828223513  17450170.0  17450150.0  1.530930e+09  14498110.0
#
#          A00200  avg_income
# 0  1.363847e+07   73.015474
# 1  8.245736e+07   59.002342
# 2  4.716417e+07   61.798674
# 3  1.272016e+08   68.375681
# 4  1.017844e+09   87.731510

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.bar(irs_wip_df_grouped_state['STATE'], height=irs_wip_df_grouped_state['A02650'])
ax.set_title('Total Individual Income by State ($100,000)', size=20)
ax.set_xticklabels(irs_wip_df_grouped_state['STATE'], rotation=90)
ax.set_xlabel('State', size=15)
ax.set_ylabel('Income', size=15)
fig.savefig('../images/total_ind_income_state.png');

# %% [markdown]
# ## NP DF Scrub

# %%
irs_np.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1764827 entries, 0 to 1764826
# Data columns (total 29 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   EIN               int64
#  2   NAME              object
#  3   ICO               object
#  4   STREET            object
#  5   CITY              object
#  6   STATE             object
#  7   ZIP               object
#  8   GROUP             int64
#  9   SUBSECTION        int64
#  10  AFFILIATION       int64
#  11  CLASSIFICATION    int64
#  12  RULING            int64
#  13  DEDUCTIBILITY     int64
#  14  FOUNDATION        int64
#  15  ACTIVITY          int64
#  16  ORGANIZATION      int64
#  17  STATUS            int64
#  18  TAX_PERIOD        float64
#  19  ASSET_CD          int64
#  20  INCOME_CD         int64
#  21  FILING_REQ_CD     int64
#  22  PF_FILING_REQ_CD  int64
#  23  ACCT_PD           int64
#  24  ASSET_AMT         float64
#  25  INCOME_AMT        float64
#  26  REVENUE_AMT       float64
#  27  NTEE_CD           object
#  28  SORT_NAME         object
# dtypes: float64(4), int64(17), object(8)
# memory usage: 390.5+ MB

# %%
np_irs_col = irs_np.drop(['Unnamed: 0','EIN','ICO','GROUP','AFFILIATION','RULING', 'DEDUCTIBILITY', 'ACTIVITY','ORGANIZATION','STATUS', 'TAX_PERIOD','ASSET_CD','INCOME_CD','FILING_REQ_CD','PF_FILING_REQ_CD','ACCT_PD','SORT_NAME'], axis=1)

# %%
np_irs_col.head()
# Out:
#                                                NAME  \
# 0                      PALMER SECOND BAPTIST CHURCH
# 1                               ST GEORGE CATHEDRAL
# 2                              IGLESIA BETHESDA INC
# 3  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC
# 4                        MERCY CHAPEL INTERNATIONAL
#
#                          STREET          CITY STATE         ZIP  SUBSECTION  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507           3
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415           3
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348           3
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242           3
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433           3
#
#    CLASSIFICATION  FOUNDATION  ASSET_AMT  INCOME_AMT  REVENUE_AMT NTEE_CD
# 0            7000          10        NaN         NaN          NaN     NaN
# 1            7000          10        NaN         NaN          NaN     NaN
# 2            7000          10        NaN         NaN          NaN     X21
# 3            7000          10        NaN         NaN          NaN     X21
# 4            7000          10        NaN         NaN          NaN     X20

# %%
np_irs_col_null = np_irs_col.dropna(axis=0).drop('STREET', axis=1)

# %%
np_irs_col_null.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 850456 entries, 12 to 1764811
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   NAME            850456 non-null  object
#  1   CITY            850456 non-null  object
#  2   STATE           850456 non-null  object
#  3   ZIP             850456 non-null  object
#  4   SUBSECTION      850456 non-null  int64
#  5   CLASSIFICATION  850456 non-null  int64
#  6   FOUNDATION      850456 non-null  int64
#  7   ASSET_AMT       850456 non-null  float64
#  8   INCOME_AMT      850456 non-null  float64
#  9   REVENUE_AMT     850456 non-null  float64
#  10  NTEE_CD         850456 non-null  object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 77.9+ MB

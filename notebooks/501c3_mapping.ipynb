# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
region1 = pd.read_csv('eo1.csv')
region2 = pd.read_csv('eo2.csv')
region3 = pd.read_csv('eo3.csv')
region4 = pd.read_csv('eo4.csv')

# %%
combined = pd.concat([region1, region2,region3, region4])

# %%
combined.head()
# Out:
#       EIN                                              NAME  ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH  NaN
# 1   29215                               ST GEORGE CATHEDRAL  NaN
# 2  587764                              IGLESIA BETHESDA INC  NaN
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC  NaN
# 4  765634                        MERCY CHAPEL INTERNATIONAL  NaN
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# 0           3            9  ...         0          0              6
# ...

# %%
combined.describe()
# Out:
#                 EIN         GROUP    SUBSECTION   AFFILIATION  CLASSIFICATION  \
# count  1.764827e+06  1.764827e+06  1.764827e+06  1.764827e+06    1.764827e+06
# mean   5.105912e+08  6.872056e+02  4.211305e+00  4.483714e+00    2.248677e+03
# std    2.579396e+08  1.790037e+03  5.971339e+00  2.607976e+00    2.105685e+03
# min    1.981800e+04  0.000000e+00  0.000000e+00  0.000000e+00    0.000000e+00
# 25%    2.731093e+08  0.000000e+00  3.000000e+00  3.000000e+00    1.000000e+03
# 50%    4.707036e+08  0.000000e+00  3.000000e+00  3.000000e+00    1.200000e+03
# 75%    8.007063e+08  2.000000e+00  3.000000e+00  6.000000e+00    2.000000e+03
# max    9.990094e+08  9.707000e+03  9.200000e+01  9.000000e+00    9.710000e+03
#
#              RULING  DEDUCTIBILITY    FOUNDATION      ACTIVITY  ORGANIZATION  \
# count  1.764827e+06   1.764827e+06  1.764827e+06  1.764827e+06  1.764827e+06
# mean   1.979862e+05   1.126717e+00  1.064384e+01  1.246068e+08  1.996666e+00
# ...

# %%
y = combined['FOUNDATION'].fillna(0)
x = combined['REVENUE_AMT'].fillna(0)

plt.scatter(x,y)

# %%
combined[combined['REVENUE_AMT']>25000000000]
# Out:
#               EIN                                       NAME  \
# 166625  311685372  SELENA THOMAS JACKSON PROFIT ORGANIZATION
# 790883  941105628                KAISER FOUNDATION HOSPITALS
# 791825  941340523          KAISER FOUNDATION HEALTH PLAN INC
#
#                                ICO                     STREET      CITY STATE  \
# 166625   % MT OLIVE UNITED MISSION            39 COTTAGE ST 2      LYNN    MA
# 790883  % CHIEF ACCOUNTING OFFICER  2701 NW VAUGHN ST STE 490  PORTLAND    OR
# 791825  % CHIEF ACCOUNTING OFFICER  2701 NW VAUGHN ST STE 490  PORTLAND    OR
#
#                ZIP  GROUP  SUBSECTION  AFFILIATION  ...  ASSET_CD  INCOME_CD  \
# 166625  01905-2306      0          91            0  ...         0          9
# 790883  97210-5358      0           3            3  ...         9          9
# 791825  97210-5358      0           3            3  ...         9          9
#
#         FILING_REQ_CD  PF_FILING_REQ_CD  ACCT_PD     ASSET_AMT    INCOME_AMT  \
# ...

# %%
removed_outliers = combined.drop([166625, 790883,791825], axis=0)

# %%
y = removed_outliers['FOUNDATION']
x = removed_outliers['REVENUE_AMT']

fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x,y)

# %%
combined['FOUNDATION'].value_counts()
'''
i'm blown away by the number of non-profits that recieve their 
funding from government support, not only the number but 
the amount of revenues that they receive. 
'''
# Out:
# 15    594703
# 16    374850
# 0     357698
# 10    260649
# 4     113564
# 11     22861
# 17     18241
# 3       7846
# 12      6026
# 21      3695
# 13      1782
# 22       812
# 9        576
# 23       524
# 14       385
# 2        335
# 24       207
# 18        57
# 25        12
# 7          2
# 6          1
# 1          1
# Name: FOUNDATION, dtype: int64

# %%
combined_fill = combined.copy()

# %%
combined_fill.fillna(0, inplace=True)

# %%
combined_fill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1764827 entries, 0 to 3927
# Data columns (total 25 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   EIN               int64
#  1   NAME              object
#  2   ICO               object
#  3   STREET            object
#  4   CITY              object
#  5   STATE             object
#  6   ZIP               object
#  7   GROUP             int64
#  8   SUBSECTION        int64
#  9   AFFILIATION       int64
#  10  CLASSIFICATION    int64
#  11  DEDUCTIBILITY     int64
#  12  FOUNDATION        int64
#  13  ACTIVITY          int64
#  14  ORGANIZATION      int64
#  15  STATUS            int64
#  16  ASSET_CD          int64
#  17  INCOME_CD         int64
#  18  FILING_REQ_CD     int64
#  19  PF_FILING_REQ_CD  int64
#  20  ACCT_PD           int64
#  21  ASSET_AMT         float64
#  22  INCOME_AMT        float64
#  23  REVENUE_AMT       float64
#  24  NTEE_CD           object
# ...

# %%
combined.head()
# Out:
#       EIN                                              NAME ICO  \
# 0   19818                      PALMER SECOND BAPTIST CHURCH   0
# 1   29215                               ST GEORGE CATHEDRAL   0
# 2  587764                              IGLESIA BETHESDA INC   0
# 3  635913  MINISTERIO APOSTOLICO JESUCRISTO ES EL SENOR INC   0
# 4  765634                        MERCY CHAPEL INTERNATIONAL   0
#
#                          STREET          CITY STATE         ZIP  GROUP  \
# 0             1050 THORNDIKE ST        PALMER    MA  01069-1507   3125
# 1                523 E BROADWAY  SOUTH BOSTON    MA  02127-4415   2365
# 2                157 ANDOVER ST        LOWELL    MA  01852-2348      0
# 3                  454 ESSEX ST      LAWRENCE    MA  01840-1242      0
# 4  75 MORTON VILLAGE DR APT 408      MATTAPAN    MA  02126-2433      0
#
#    SUBSECTION  AFFILIATION  ...  STATUS  ASSET_CD  INCOME_CD  FILING_REQ_CD  \
# ...

# %%
state_NTEE_count = combined.groupby(['STATE','NTEE_CD']).count()
state_NTEE_count
# Out:
#                EIN  NAME  ICO  STREET  CITY  ZIP  GROUP  SUBSECTION  \
# STATE NTEE_CD
# 0     0        417   417  417     417   417  417    417         417
#       A01        1     1    1       1     1    1      1           1
#       A11        2     2    2       2     2    2      2           2
#       A110       1     1    1       1     1    1      1           1
#       A115       1     1    1       1     1    1      1           1
# ...            ...   ...  ...     ...   ...  ...    ...         ...
# WY    Y43        3     3    3       3     3    3      3           3
#       Y50        1     1    1       1     1    1      1           1
#       Y99        2     2    2       2     2    2      2           2
#       Z99       13    13   13      13    13   13     13          13
#       Z99Z       6     6    6       6     6    6      6           6
#
#                AFFILIATION  CLASSIFICATION  ...  ORGANIZATION  STATUS  \
# STATE NTEE_CD                               ...
# ...

# %%
combined.STATE.dropna(axis=0, inplace=True)

# %%
combined.groupby('STATE').sum()
# Out:
# 0       MA
# 1       MA
# 2       MA
# 3       MA
# 4       MA
#         ..
# 3912    FM
# 3917    MP
# 3924    PR
# 3925    MP
# 3926    MP
# Name: STATE, Length: 1763518, dtype: object

# %%
state_count = combined.STATE.value_counts()
states = combined['STATE'].unique()
state_count_dict = dict(state_count)

key_ = state_count_dict.keys()
value_ = state_count_dict.values()

# %%
key_[0]
# Out:
# -------------------------------------------------
# NameError       Traceback (most recent call last)
# <ipython-input-1-c9dcc9694721> in <module>
# ----> 1 key_[0]
#
# NameError: name 'key_' is not defined

# %%
plt.bar(keys, values)
# Out:
# --------------------------------------------------
# TypeError        Traceback (most recent call last)
# <ipython-input-148-2b8dd93b1f71> in <module>
# ----> 1 plt.bar(keys, values)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2345
# ...
